# %%
import pandas as pd 
data = {
   '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
   '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
   '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
   '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
### DataFrame 변경 
df = pd.DataFrame(data)

# %% [markdown]
# 퀴즈 : index를 영화로 지정해서 역순정렬하시오

# %%
# 1.index 영화로 지정
df.set_index('영화',inplace=True)
df
# Out:
#            개봉 연도  관객 수    평점
# 영화
# 명량          2014  1761  8.88
# 극한직업        2019  1626  9.20
# 신과함께-죄와 벌   2017  1441  8.73
# 국제시장        2014  1426  9.16
# 괴물          2006  1301  8.62
# 도둑들         2012  1298  7.64
# 7번방의 선물     2013  1281  8.83
# 암살          2015  1270  9.10

# %%
#2.역순정렬 
df.sort_index(ascending=False,inplace=True)
df
# Out:
#            개봉 연도  관객 수    평점
# 영화
# 암살          2015  1270  9.10
# 신과함께-죄와 벌   2017  1441  8.73
# 명량          2014  1761  8.88
# 도둑들         2012  1298  7.64
# 극한직업        2019  1626  9.20
# 국제시장        2014  1426  9.16
# 괴물          2006  1301  8.62
# 7번방의 선물     2013  1281  8.83

# %%
# 평점에대한평균 2. 최대 관객수 3. 최소관객수를 구하시오 
#1.df["평점"].mean()
#2.df["관객 수"].nlargest(1)
#3.df["관객 수"].nsmallest(1)

# %%
df['관객 수'].nlargest()
# Out:
# 영화
# 명량           1761
# 극한직업         1626
# 신과함께-죄와 벌    1441
# 국제시장         1426
# 괴물           1301
# Name: 관객 수, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 암살 to 7번방의 선물
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   개봉 연도   8 non-null      int64
#  1   관객 수    8 non-null      int64
#  2   평점      8 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 556.0+ bytes

# %%
df.describe()
# Out:
#             개봉 연도         관객 수        평점
# count     8.00000     8.000000  8.000000
# mean   2013.75000  1425.500000  8.770000
# std       3.84522   181.193661  0.501797
# min    2006.00000  1270.000000  7.640000
# 25%    2012.75000  1293.750000  8.702500
# 50%    2014.00000  1363.500000  8.855000
# 75%    2015.50000  1487.250000  9.115000
# max    2019.00000  1761.000000  9.200000
