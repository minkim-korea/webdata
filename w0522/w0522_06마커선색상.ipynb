# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #windows 한글폰트 연결 
#matplotlib.rcParams['font.family'] = 'AppleGothic' #mac 한글폰트연결
matplotlib.rcParams['font.size'] =15   # 폰트사이즈 
matplotlib.rcParams['axes.unicode_minus'] = False # 그래프  마이너스 표시

# %%
x = [1,2,3,4,5]
y =[10,20,22,25,29]

# %%
df = pd.read_excel("data/score.xlsx",index_col='지원번호')  #ctrl spacebar

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %%
#label : 범례 , linewidth : 선의두께  
#marker : 지점에 마커표시 o ,v ,x ,s,  
#   (ls선제거)linestyle='None':선제거, :점선, --대쉬선 , -.점선점 color :선색상 
#마커형태
#markeredgecolor 마커테두리 mec, markerfacecolor mfc : 마커색상 ,alpha 투명도
#marketsize
##color,마커모양 o ,선스타일 -- ,
plt.plot(x,y,'rv--',label='서울',mec='b',mfc='yellow') # r 선색상 , o는 마커모양 , --는 선스타일 
#plt.plot(x,y,'ro--',label='서울',linewidth=5) # r 선색상 , o는 마커모양 , --는 선스타일 
#plt.plot(x,y,label='서울',linewidth=2,marker="o",markersize=10,alpha=0.7,
 #        mec='red',mfc='yellow',linestyle='-.',color='red'
    #     ) # 꺾은선그래프 
#plt.plot(x,y,label='서울',linewidth=2,marker="o",markersize=10,linestyle='None') # 꺾은선그래프 
#plt.plot(df['이름'],df['국어']) #리스트입력시 그래프나타남
plt.title('그래프') # 한글지원부분설정 
#loc범례위치- y축: upper,center,lower x축 left center right 
#위치점 지정(loc=(0.5,0.5)) #가운데지점
#plt.legend(loc=(0.25,0.5)) 
plt.legend()
plt.show()    #실행구문 제거

# %%
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80         NaN
# 5번     김구   가산고  188   15   20   10  35  10         NaN
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
plt.plot(df['이름'],df['국어'],label='국어',marker="o")
plt.plot(df['이름'],df['영어'],label='영어',marker="v",alpha=0.2)
plt.plot(df['이름'],df['수학'],label='수학',marker="x",alpha=0.2)
plt.title("학생성적그래프")
plt.legend()
plt.show()

# %%
df = pd.read_csv("data/stuscore.csv",index_col='번호')
df1 =df.head(3)
df1

# df1 이름, 국어 ,선색 :파란색 o
# df1 이름, 영어 ,선색: 초록색 v 핑크 
# df1 이름, 수학 ,선색: 빨간색 x 
# 그래프를 출력하시오 .
# Out:
#      이름  국어  영어  수학
# 번호
# 1   홍길동  71  80  74
# 2   유관순  53  91  75
# 3   이순신  53  83  78

# %%
plt.plot(df1['이름'],df1['국어'],'bo-',label=df.columns[1])
plt.plot(df1['이름'],df1['영어'],'gv-',color='pink',label=df.columns[2])
plt.plot(df1['이름'],df1['수학'],'rx-',label=df.columns[3])
plt.title("학생성적그래프")
plt.legend()
plt.show()
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_15436\3928989058.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "gv-" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(df1['이름'],df1['영어'],'gv-',color='pink',label=df.columns[2])
