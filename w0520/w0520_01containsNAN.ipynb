# %%
import pandas as pd 
df =pd.read_excel('data/score.xlsx',index_col='지원번호')

# %%
### column출력
df['키']
df[['이름','키']]
df[df.columns[2:5]]
df.columns
df[1:5] # row 출력 

### row출력 
df[1:5]
df.loc['1번']
df.loc[['1번','2번','3번']]
df.loc['1번':'3번'][['키','SW특기']]
# Out:
#         키        SW특기
# 지원번호
# 1번    197      Python
# 2번    184        Java
# 3번    168  Javascript

# %%
### column출력
df['키']
df[['이름','키']]
df[df.columns[2:5]]
df.columns
df[1:5] # row 출력 

### row출력 
df[1:5]
df.loc['1번']
df.loc[['1번','2번','3번']]
df.loc['1번':'3번'][['키','SW특기']]
df.loc['1번':'3번']['키']
df.loc['1번':'3번','키':"수학"] # 슬라이싱 출력 
df.iloc[0] #번호로 출력 
df.iloc[0:3] #번호로 출력 
df.iloc[[0,3,5]] #번호로 출력 
df.iloc[0:3][['키','수학']]
df.iloc[0:3,1:5]
# Out:
#        학교    키  국어  영어
# 지원번호
# 1번    가산고  197  90  85
# 2번    가산고  184  40  35
# 3번    가산고  168  80  75

# %%
###조건식
filt = df['키']>=190
df[filt]
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회    SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85  Python
# 6번    김유신  디지털고  202   80  100   95  85  80       C
# 8번    홍길순  디지털고  190  100   85   90  95  95      C#

# %%
df['키']>=190
# Out:
# 지원번호
# 1번     True
# 2번    False
# 3번    False
# 4번    False
# 5번    False
# 6번     True
# 7번    False
# 8번     True
# Name: 키, dtype: bool

# %%
# & ,|
df[df['키']>=190]
df[(df['키']>=190) & (df['국어']>=90)]
df[(df['키']>=190) | (df['국어']>=90)]
df[~(df['키']>=190)]  ### not
# Out:
#        이름    학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    유관순   가산고  184  40  35  50  55  25        Java
# 3번    이순신   가산고  168  80  75  70  80  75  Javascript
# 4번    강감찬   가산고  187  40  60  70  75  80         NaN
# 5번     김구   가산고  188  15  20  10  35  10         NaN
# 7번    홍길자  디지털고  188  55  65  45  40  35      PYTHON

# %%
filt = df['이름'].str.contains("순") # 순이 포함되어있는 문자 
df[filt]
filt = df['이름'].str.endswith("순") # 마지막 글자 
df[filt]
filt = df['이름'].str.startswith("홍")# 첫 글자 
df[filt]
# Out:
#        이름    학교    키   국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    홍길동   가산고  197   90  85  100  95  85  Python
# 7번    홍길자  디지털고  188   55  65   45  40  35  PYTHON
# 8번    홍길순  디지털고  190  100  85   90  95  95      C#

# %%
arr = ['python','java']
filt = df['SW특기'].isin(arr) # 리스트 타입을 가지고 일치하는것을 검색  (대소문자구분)
df[filt]
df['SW특기'].str.lower()  #소문자 변경 
df['SW특기'].str.upper()  #대문자 변경
filt = df['SW특기'].str.lower().isin(arr)
df[filt]
df
### java 포함되어있는글자도 출력하시오 .
filt = df['SW특기'].str.lower().str.contains("java")
#df[filt]
#df['SW특기'].str.lower().str.contains("java")
# contains - NaN 데이터 처리를 별도로처리해야함 
df['SW특기'].str.contains("java",na=True) #na : NAN데이터 처리 False 검색되지않음 
df['SW특기'].str.contains("java",na=False) #na : NAN데이터 처리 False 검색되지않음 
df[filt]
filt = df['SW특기'].str.lower().str.contains("java",na=True) 
df[filt]

df.info()
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    유관순  가산고  184  40  35  50  55  25        Java
# 3번    이순신  가산고  168  80  75  70  80  75  Javascript
# 4번    강감찬  가산고  187  40  60  70  75  80         NaN
# 5번     김구  가산고  188  15  20  10  35  10         NaN

# %%
arr = ['python','java']
filt = df['SW특기'].str.lower().isin(arr)
df[filt]
filt = df['SW특기'].str.lower().str.contains('p',na=False)
df[filt]
# Out:
#        이름    학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197  90  85  100  95  85      Python
# 3번    이순신   가산고  168  80  75   70  80  75  Javascript
# 7번    홍길자  디지털고  188  55  65   45  40  35      PYTHON
